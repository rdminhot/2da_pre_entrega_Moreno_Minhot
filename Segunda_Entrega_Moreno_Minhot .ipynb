# %% [markdown]
# # 2  da. Pre-entrega
#
#
#  Equipo Integrado por Sergio Antonio Moreno Banda y Ricardo David Minhot
#
#
# ## Tutora Maris Botero
#
#
# # Datasets "Cáncer de Pulmón"
#
#
# ### Datos: (int), (str)
#
# ## Existen factores predisponentes en la enfermedad de cáncer de pulmón?
# ## Abstract:
# ### Se realizará un estudio desde la perspectiva de la presencia o no de factores predisponentes en el cáncer de pulmón. El cáncer de pulmón, según el National Cancer institute, a diferencia de otros tipos de cáncer que aparecen más relacionados a variables como el sexo o la edad, es una enfermedad que afecta en igual medida a hombres y mujeres, siendo una de las enfermedades de cáncer más frecuentes en el mundo. Este trabajo está motivado por lograr desenmascarar aquellos factores predisponentes que existieran con el fin de prevenir, a la población mundial, a una exposición prolongada en el tiempo a dichos factores a fin de minimizar el riesgo a contraer la enfermedad.
# ### Sobre la base de un Dataset tomado del sitio Kaggle realizaremos un estudio a fin de evaluar la enfermedad de cancer de pulmón y de si existen factores predisponentes a la enfermedad o no.
# ### Se evaluará la correlación entre las diferentes variables del modelo y la variable a analizar( cáncer de pulmón)
# ### Se analizarán cáncer de pulmón presente y ausente con las demás variables. En caso de arrojar valores semejantes podremos aceptar la Ho dado que no existirían factores predisponentes a la aparición de cáncer de pulmón descartando la hipótesis H1. En caso contrario tomará preponderancia la H1 verificando la existencia de correlación entre las variables analizadas.
# ### Serán elaborados gráficos con la utilización de librerías como Seaborn, Matplotlib, etc, a fin de tener una visualización de la relación entre variables, cuantificación de casos, etc, a la vez que se intentarán definir insight que nos aporten valor a la investigación.
# ### Hipótesis nula (Ho) de que no existen factores predisponentes al origen del cáncer de pulmón en humanos, es decir que la ocurrencia de cáncer de pulmón es independiente de las demás variables a analizar sobre una muestra tomada al azar en una población y en un rango etario determinado.
# ### Hipótesis alternativa (H1) de que la aparición de cáncer de pulmón tiene factores predisponentes.
# ## OBJETIVO:
# ### En base al análisis de hipótesis poder defininir la profilaxis a seguir a fin de evitar un desarrollo temprano de la enfermedad, minimizando el  riesgo, es decir elaborando un plan de aviso para evitar que los factores predisponentes  tengan una presencia significativa en la vida diaria de las personas en caso de que estos existan. Estimamos  que esto sería de importancia relevante para que las personas estén distanciadas de la enfermedad, que no solo ocaciona muertes de importancia en la población sino que también genera una calidad de vida deprimida para quienes la padecen.
# ## EDA:
# ### Se realizó un análisis exploratorio de datos preliminar con la utilización de diferentes librerías para visualización, comparando o relacionando las diferentes variables entre si.
# ### En una primera aproximación a estas visualizaciones notamos una cierta y aparente independencia en cuanto a que existiera algún factor predisponente a la enfermedad. Se graficaron los datos a nivel univariado, bivariado y multivariado.
# ### El desafío siguiente es aplicar diferentes estadísticos, métricas y algoritmos de machine lerning a nuestra base de datos con el objetivo de contrastar hipótesis. Se aplicará Análisis supervisado de clasificación con sus algoritmos y métricas correspondientes.
# -
# ##  Columnas Datasets de Cancer
#
#
# ### GÉNERO: El género de los sujetos, M o F
# ### EDAD: La edad de los sujetos
# ### FUMAR: 2 si fuman y 1 si no lo hacen.
# ### YELLOW_FINGERS: 2 si tienen los dedos amarillos y 1 si no los tienen.
# ### ANSIEDAD: 2 si están sufriendo ansiedad y 1 si no la  sufren.
# ### PEER_PRESSURE: 2 si están influenciados por el entorno fumador y 1 si no lo están.
# ### ENFERMEDAD CRÓNICA: 2 si tienen una enfermedad crónica y 1 si no lo tienen.
# ### FATIGA: 2 si se fatigan fácilmente y 1 si no lo están
# ### ALERGIA: 2 si tienen alergia y 1 si no la tienen.
# ### SIBILANCIAS: 2 si jadean y 1 si no lo hacen.
# ### CONSUMO DE ALCOHOL: 2 si consumen alcohol y 1 si no lo hacen.
# ### TOS: 2 si tosen regularmente y 1 si no lo hacen.
# ### DIFICULTAD PARA RESPIRAR: 2 si experimentan dificultad para respirar y 1 si no lo hacen.
# ### DIFICULTAD PARA TRAGAR: 2 si tienen problemas para tragar y 1 si no lo tienen.
# ### DOLOR EN EL PECHO: 2 si tienen dolor en el pecho y 1 si no lo tienen.
# ### LUNG_CANCER: SÍ si son positivos con cáncer de pulmón y NO si no lo son.
# ### Esta es la columna que estamos tratando de predecir.

# %%
import pandas as pd
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#ruta= "C:/Users/Sergio-PC/Desktop/Data science/Datasets"

# %%
Cancer=pd.read_csv("C:/Users/David/Documents/Davo/cursos/data/Scientist/Cancer.csv")

# %%
print(f"Forma del Conjunto de Datos : {Cancer.shape}")
print(f"\n\nVisualización del dataset :\n")
Cancer.head()
# Out:
# Forma del Conjunto de Datos : (7651, 16)
#
#
# Visualización del dataset :
#   GENDER  AGE  SMOKING  YELLOW_FINGERS  ANXIETY  PEER_PRESSURE  \
# 0      M   69        1               2        2              1
# 1      M   74        2               1        1              1
# 2      F   59        1               1        1              2
# 3      M   63        2               2        2              1
# 4      F   63        1               2        1              1
#
#    CHRONIC DISEASE  FATIGUE   ALLERGY   WHEEZING  ALCOHOL CONSUMING  COUGHING  \
# 0                1         2         1         2                  2         2
# 1                2         2         2         1                  1         1
# 2                1         2         1         2                  1         2
# 3                1         1         1         1                  2         1
# 4                1         1         1         2                  1         2
#
# ...

# %%
print(f"Información Sobre el Conjunto de Datos :\n")
print(Cancer.info())
# Out:
# Información Sobre el Conjunto de Datos :
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7651 entries, 0 to 7650
# Data columns (total 16 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   GENDER                 7651 non-null   object
#  1   AGE                    7651 non-null   int64
#  2   SMOKING                7651 non-null   int64
#  3   YELLOW_FINGERS         7651 non-null   int64
#  4   ANXIETY                7651 non-null   int64
#  5   PEER_PRESSURE          7651 non-null   int64
#  6   CHRONIC DISEASE        7651 non-null   int64
#  7   FATIGUE                7651 non-null   int64
#  8   ALLERGY                7651 non-null   int64
#  9   WHEEZING               7651 non-null   int64
#  10  ALCOHOL CONSUMING      7651 non-null   int64
#  11  COUGHING               7651 non-null   int64
#  12  SHORTNESS OF BREATH    7651 non-null   int64
#  13  SWALLOWING DIFFICULTY  7651 non-null   int64
# ...

# %% [markdown]
# ## Búsqueda de datos nulos (missing values)

# %%
Cancer.isnull().values.any()
# Out:
# False

# %% [markdown]
# ## Verificación de duplicados y eliminación de los mismos.

# %%
dup = Cancer[Cancer.duplicated()].shape[0]
print(f"Hay {dup} entradas duplicadas entre {Cancer.shape[0]}  entradas en este conjunto de datos.")

Cancer.drop_duplicates(keep='first',inplace=True)
print(f"\nDespués de eliminar las entradas duplicadas hay {Cancer.shape[0]} entradas en este conjunto de datos.")
# Out:
# Hay 0 entradas duplicadas entre 7605  entradas en este conjunto de datos.
#
# Después de eliminar las entradas duplicadas hay 7605 entradas en este conjunto de datos.

# %%
sns.set_style("whitegrid")
sns.set_context("poster",font_scale = .7)

palette = ["#1d7874","#679289","#f4c095","#ee2e31","#ffb563","#918450","#f85e00","#a41623","#9a031e","#d6d6d6","#ffee32","#ffd100","#333533","#202020"]

# sns.palplot(sns.color_palette(palette))
# plt.show()

# %% [markdown]
# ## Reemplazamos en feature  GENDER las clases "M" y "F" por "Male" y "Female".

# %%
#data_temp = Cancer.copy()
Cancer["GENDER"] = Cancer["GENDER"].replace({"M" : "Male" , "F" : "Female"})

#for column in data_temp.columns:
    #data_temp[column] = data_temp[column].replace({2: "Yes" , 1 : "No"})
#data_temp.head(20)

# %% [markdown]
# ## Visualizacción de primeros insight a partir de la correlación entre casos de cáncer positivo en relación al sexo como también a la edad. Para esto construiremos un dataset temporal con casos cáncer positivo y luego compararemos las gráficas con el dataset con cáncer positivo y negativo.

# %%
print(f"\n\nVisualización del dataset con casos positivos unicamente:\n")
Cancer_pos = Cancer[Cancer["LUNG_CANCER"] == "YES"]
Cancer_pos.head()
# Out:
# Visualización del dataset con casos positivos unicamente:
#    GENDER  AGE  SMOKING  YELLOW_FINGERS  ANXIETY  PEER_PRESSURE  \
# 0    Male   69        1               2        2              1
# 1    Male   74        2               1        1              1
# 5  Female   75        1               2        1              1
# 6    Male   52        2               1        1              1
# 7  Female   51        2               2        2              2
#
#    CHRONIC DISEASE  FATIGUE   ALLERGY   WHEEZING  ALCOHOL CONSUMING  COUGHING  \
# 0                1         2         1         2                  2         2
# 1                2         2         2         1                  1         1
# 5                2         2         2         2                  1         2
# 6                1         2         1         2                  2         2
# 7                1         2         2         1                  1         1
#
# ...

# %% [markdown]
# ## Explorando la distribución por género en casos cáncer positivos y su possterior comparación con gráafica de dataset  completo.

# %%
plt.subplots(figsize=(12, 12))

labels = "Male","Female"
size = 0.7

wedges, texts, autotexts = plt.pie([len(Cancer_pos[Cancer_pos["GENDER"]=="Male"]["GENDER"]),
                                    len(Cancer_pos[Cancer_pos["GENDER"]=="Female"]["GENDER"])],
                                    explode = (0.1,0),
                                    textprops=dict(size= 25, color= "white"),
                                    autopct="%.2f%%", 
                                    pctdistance = 0.5,
                                    radius=.9, 
                                    colors = ["#a2c4c9","#aa7e4f"], 
                                    shadow = True,
                                    wedgeprops=dict(width = size, edgecolor = "white", 
                                    linewidth = 5),
                                    startangle = 0)

plt.legend(wedges, labels, title="Categoria",loc="center left",bbox_to_anchor=(1, 0, 0.5, 1))
plt.title("\nCasos positivos de cáncer-Distribución por género",fontsize=20)
plt.show()

# %% [markdown]
# ## Subdivisión de columna GENDER en subcolumnas MALE y FEMALE y reasignación de nuevos nombres a las  features.

# %%
from sklearn.preprocessing import LabelEncoder 
LabelEncoder = LabelEncoder()

Cancer["GENDER"] = Cancer["GENDER"].replace({"M" : "Male" , "F" : "Female"})
Cancer["LUNG_CANCER"] = LabelEncoder.fit_transform(Cancer["LUNG_CANCER"])

Cancer = pd.get_dummies(Cancer, columns= ["GENDER"])
Cancer.rename(columns={"GENDER_Male" : "MALE", "GENDER_Female" : "FEMALE", "YELLOW_FINGERS" : "YELLOW FINGERS", "PEER_PRESSURE" : "PEER PRESSURE", "LUNG_CANCER" : "LUNG CANCER", "FATIGUE " : "FATIGUE", "ALLERGY " : "ALLERGY"}, inplace=True)
Cancer = Cancer[["AGE","SMOKING","MALE","FEMALE","ALCOHOL CONSUMING","CHEST PAIN","SHORTNESS OF BREATH","COUGHING","PEER PRESSURE","CHRONIC DISEASE","SWALLOWING DIFFICULTY","YELLOW FINGERS","ANXIETY","FATIGUE","ALLERGY","WHEEZING","LUNG CANCER"]]
Cancer.head(5)
# Out:
#    AGE  SMOKING  MALE  FEMALE  ALCOHOL CONSUMING  CHEST PAIN  \
# 0   69        1     1       0                  2           2
# 1   74        2     1       0                  1           2
# 2   59        1     0       1                  1           2
# 3   63        2     1       0                  2           2
# 4   63        1     0       1                  1           1
#
#    SHORTNESS OF BREATH  COUGHING  PEER PRESSURE  CHRONIC DISEASE  \
# 0                    2         2              1                1
# 1                    2         1              1                2
# 2                    2         2              2                1
# 3                    1         1              1                1
# 4                    2         2              1                1
#
#    SWALLOWING DIFFICULTY  YELLOW FINGERS  ANXIETY  FATIGUE  ALLERGY  WHEEZING  \
# 0                      2               2        2        2        1         2
# ...

# %% [markdown]
# ## Visualización  de distribución por género en relación a efecto del tabaquismo y consumo  de alcohol en casos de cáncer positivo y su comparación a  gráfcia de dataset completo.

# %%
_, axs = plt.subplots(1,2,figsize=(20,8),sharex=True,sharey=True)
plt.tight_layout(pad=4.0)

sns.countplot(data=Cancer_pos,x="GENDER",hue="SMOKING",hue_order=[2, 1],ax=axs[0],palette=["#a2c4c9","#aa7e4f"],saturation=1)
axs[0].set_title("\nEfecto del Tabaquismo\n",fontsize=20)
axs[0].set_xlabel("GENDER")
axs[0].set_ylabel("Quantity")
for container in axs[0].containers:
    axs[0].bar_label(container,label_type="center",padding=2,size=25,color="white",rotation=0)

sns.countplot(data=Cancer_pos,x="GENDER",hue="ALCOHOL CONSUMING",hue_order=[2, 1],ax=axs[1],palette=["#a2c4c9","#aa7e4f"],saturation=1)
axs[1].set_title("\nEfectos del consumo de Alcohol\n",fontsize=20)
axs[1].set_xlabel("GENDER")
axs[1].set_ylabel("Quantity")
for container in axs[1].containers:
    axs[1].bar_label(container,label_type="center",padding=2,size=25,color="white",rotation=0)

sns.despine(left=True, bottom=True)
plt.show()

# %% [markdown]
# ## Matriz de correlación de Pearson sobre dataset original.

# %%
plt.subplots(figsize =(16, 12))

p=sns.heatmap(Cancer.corr(), cmap = palette, square=True, cbar_kws=dict(shrink =.99), 
            annot=True, vmin=-1, vmax=1, linewidths=0.3,linecolor='white',annot_kws=dict(fontsize =12))
p.axes.set_title("Pearson Correlation Of Features\n", fontsize=25)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ## Distribución de casos de cáncer positivo por edad.

# %%
sns.displot(Cancer_pos, x="AGE", col="LUNG_CANCER")

# %% [markdown]
# # Obtención de insights a partir de visualizaciones:

# %% [markdown]
# ## Insights: En una primera observación de gráficas de los datos y en un acercamiento a las hipótesis de trabajo se verifica que la aparición de Cancer de Pulmón es una enfermedad que se manifiesta en el ser humano con independencia del sexo y de la edad.

# %% [markdown]
# # Feature Selection :
# ## -Definición de varible X (Predictora) y variable Y (Respuesta).
# ## -Proceso de selección de features más predictivas.

# %%
#Cancer['LUNG CANCER'] = Cancer.target Este codigo si no está no afecta lo que sigue. Porqué?
X= Cancer.drop('LUNG CANCER',1)
Y= Cancer['LUNG CANCER']
Cancer.head()
# Out:
# C:\Users\David\AppData\Local\Temp\ipykernel_6364\1401682319.py:2: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   X= Cancer.drop('LUNG CANCER',1)
#    AGE  SMOKING  MALE  FEMALE  ALCOHOL CONSUMING  CHEST PAIN  \
# 0   69        1     1       0                  2           2
# 1   74        2     1       0                  1           2
# 2   59        1     0       1                  1           2
# 3   63        2     1       0                  2           2
# 4   63        1     0       1                  1           1
#
#    SHORTNESS OF BREATH  COUGHING  PEER PRESSURE  CHRONIC DISEASE  \
# 0                    2         2              1                1
# 1                    2         1              1                2
# 2                    2         2              2                1
# 3                    1         1              1                1
# ...

# %%
X.head()
# Out:
#    AGE  SMOKING  MALE  FEMALE  ALCOHOL CONSUMING  CHEST PAIN  \
# 0   69        1     1       0                  2           2
# 1   74        2     1       0                  1           2
# 2   59        1     0       1                  1           2
# 3   63        2     1       0                  2           2
# 4   63        1     0       1                  1           1
#
#    SHORTNESS OF BREATH  COUGHING  PEER PRESSURE  CHRONIC DISEASE  \
# 0                    2         2              1                1
# 1                    2         1              1                2
# 2                    2         2              2                1
# 3                    1         1              1                1
# 4                    2         2              1                1
#
#    SWALLOWING DIFFICULTY  YELLOW FINGERS  ANXIETY  FATIGUE  ALLERGY  WHEEZING
# 0                      2               2        2        2        1         2
# ...

# %%
Y.head()
# Out:
# 0    1
# 1    1
# 2    0
# 3    0
# 4    0
# Name: LUNG CANCER, dtype: int32

# %% [markdown]
# ## Aplicando Forward selection  a un nivel de significancia del 0,05.

# %%
import statsmodels.api as sm
def forward_selection(Cancer, target, significance_level=0.05): 
    initial_features = Cancer.columns.tolist()
    best_features = []
    while (len(initial_features)>0):
        remaining_features = list(set(initial_features)-set(best_features))
        new_pval = pd.Series(index=remaining_features)
        for new_column in remaining_features:
            model = sm.OLS(target, sm.add_constant(Cancer[best_features+[new_column]])).fit()
            new_pval[new_column] = model.pvalues[new_column]
        min_p_value = new_pval.min()
        if(min_p_value<significance_level):
            best_features.append(new_pval.idxmin())
        else:
            break
    return best_features

# %%
forward_selection(X,Y)
# Out:
# C:\Users\David\AppData\Local\Temp\ipykernel_6364\2873425038.py:7: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   new_pval = pd.Series(index=remaining_features)
# C:\Users\David\AppData\Local\Temp\ipykernel_6364\2873425038.py:7: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   new_pval = pd.Series(index=remaining_features)
# C:\Users\David\AppData\Local\Temp\ipykernel_6364\2873425038.py:7: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   new_pval = pd.Series(index=remaining_features)
# ...

# %% [markdown]
# ## Eliminación de variables no predictoras y nueva denominación del dataset "Cancer_1"

# %%
Cancer_1= Cancer.drop(['AGE', 'MALE', 'FEMALE', 'ALCOHOL CONSUMING', 'CHEST PAIN','COUGHING', 'PEER PRESSURE', 'CHRONIC DISEASE',
       'SWALLOWING DIFFICULTY','ANXIETY',
       'ALLERGY', 'WHEEZING', 'SMOKING'], axis=1)
Cancer_1.head()
# Out:
#    SHORTNESS OF BREATH  YELLOW FINGERS  FATIGUE  LUNG CANCER
# 0                    2               2        2            1
# 1                    2               1        2            1
# 2                    2               1        2            0
# 3                    1               2        1            0
# 4                    2               2        1            0

# %%
X1= Cancer_1.drop('LUNG CANCER',1)
Y1= Cancer_1['LUNG CANCER']
Cancer_1.head()
# Out:
# C:\Users\David\AppData\Local\Temp\ipykernel_6364\1741769851.py:1: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   X1= Cancer_1.drop('LUNG CANCER',1)
#    SHORTNESS OF BREATH  YELLOW FINGERS  FATIGUE  LUNG CANCER
# 0                    2               2        2            1
# 1                    2               1        2            1
# 2                    2               1        2            0
# 3                    1               2        1            0
# 4                    2               2        1            0

# %%
X1.head()
# Out:
#    SHORTNESS OF BREATH  YELLOW FINGERS  FATIGUE
# 0                    2               2        2
# 1                    2               1        2
# 2                    2               1        2
# 3                    1               2        1
# 4                    2               2        1

# %%
Y1.head()
# Out:
# 0    1
# 1    1
# 2    0
# 3    0
# 4    0
# Name: LUNG CANCER, dtype: int32

# %% [markdown]
# ## Métricas

# %%
 from sklearn.ensemble import RandomForestClassifier
 from sklearn.model_selection import train_test_split
 from sklearn import metrics
 #import pandas as pd
 #import numpy as np
 #from matplotlib import pyplot as plt
 #import seaborn as sns
 sns.set_style('whitegrid')

# %%
#pd.Series(Cancer['LUNG CANCER'])

# %% [markdown]
# ## Set de entrenamiento y testeo

# %%
X_train, X_test, y_train, y_test = train_test_split(X1,Y1,test_size=0.3, random_state=1)
 #Creamos un modelo Random Forest con parametros por defect
modelo = RandomForestClassifier(random_state=1)
modelo.fit(X_train, y_train)
# Obtenemos las predicciones del modelo con X_test
preds = modelo.predict(X_test)

# %%
plt.figure(figsize=(10,6))
metrics.plot_confusion_matrix(modelo, X_test, y_test, display_labels=['POSITIVO', 'NEGATIVO'])
# Out:
# C:\Users\David\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function plot_confusion_matrix is deprecated; Function `plot_confusion_matrix` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: ConfusionMatrixDisplay.from_predictions or ConfusionMatrixDisplay.from_estimator.
#   warnings.warn(msg, category=FutureWarning)

# %%
confusion = metrics.confusion_matrix(y_test, preds)
confusion.ravel()
# Out:
# array([684, 393, 749, 456], dtype=int64)

# %% [markdown]
# ## Accuracy

# %%
accuracy = metrics.accuracy_score(y_test, preds)
accuracy
# Out:
# 0.49956178790534617

# %% [markdown]
# ## Precisión

# %%
precision_positiva = metrics.precision_score(y_test, preds, pos_label=1)
precision_negativa = metrics.precision_score(y_test, preds, pos_label=0)
precision_positiva, precision_negativa
# Out:
# (0.5371024734982333, 0.47732030704815076)

# %% [markdown]
# ## Recall

# %%
recall_sensibilidad = metrics.recall_score(y_test, preds, pos_label=1)
recall_especificidad= metrics.recall_score(y_test, preds, pos_label=0)
recall_sensibilidad, recall_especificidad
# Out:
# (0.3784232365145228, 0.6350974930362117)

# %% [markdown]
# ## F1 Score

# %%
f1_positivo = metrics.f1_score(y_test, preds, pos_label=1)
f1_negativo = metrics.f1_score(y_test, preds, pos_label=0)
f1_positivo, f1_negativo
# Out:
# (0.44401168451801365, 0.545019920318725)

# %%
print(metrics.classification_report(y_test, preds))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.48      0.64      0.55      1077
#            1       0.54      0.38      0.44      1205
#
#     accuracy                           0.50      2282
#    macro avg       0.51      0.51      0.49      2282
# weighted avg       0.51      0.50      0.49      2282

# %% [markdown]
# ## Conclusiones:
# ### Observamos valores semejantes en todas las métricas utilizadas, rondando los mismos en valores cercanos a 0,5. Dado esto, estimamos que quedan dudas a cerca de que tan buen predictoras son laas features. Entendemos que el modelo se equivoca en un valor cercano al 50% dando valores de FP y FN semejantes a TP y TN.¶

# %% [markdown]
# ## Observaciónes.
# ### En función de lo observado estimamos estar frente a una situación de Underfitting. Deberíamos tener features más predictoras o mayor cantidad de instancias para las features que los modelos estiman.

# %% [markdown]
# ## Objetivos:
# ### Lograr definir un dataset con features de mayor poder predictivo con el objetivo de que el modelo sea confiable a futuras evaluaciones.
